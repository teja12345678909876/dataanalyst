# %% [markdown]
# <a href="https://colab.research.google.com/github/teja12345678909876/dataanalyst/blob/main/mean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets

# %%
import opendatasets as od

# %%
od.download("https://www.kaggle.com/datasets/positivealexey/youtube-channel-performance-analytics")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: rohithnagateja
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/positivealexey/youtube-channel-performance-analytics
# ...
# 100%|██████████| 40.5k/40.5k [00:00<00:00, 18.1MB/s]

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/youtube-channel-performance-analytics/youtube_channel_real_performance_analytics.csv')

# %%
data.head()
# Out:
#    ID  Video Duration   Video Publish Time  Days Since Publish  Day  Month  \
# 0   0           201.0  2016-06-02 00:00:00                   0    2      6
# 1   1           391.0  2016-06-10 00:00:00                   8   10      6
# 2   2           133.0  2016-06-14 00:00:00                   4   14      6
# 3   3            14.0  2016-06-29 00:00:00                  15   29      6
# 4   4            45.0  2016-07-01 00:00:00                   2    1      7
#
#    Year Day of Week  Revenue per 1000 Views (USD)  \
# 0  2016    Thursday                         0.024
# 1  2016      Friday                         0.056
# 2  2016     Tuesday                         0.014
# 3  2016   Wednesday                         0.004
# 4  2016      Friday                         0.000
#
#    Monetized Playbacks (Estimate)  ...  Watched (Not Skipped) (%)  \
# 0                           723.0  ...                        0.0
# 1                           727.0  ...                        0.0
# ...

# %%
import pandas as pd
import numpy as np
from scipy import stats

# Assuming 'data' is your DataFrame and 'Views' is the numerical column
column_name = 'Views'

# Calculate Mean
mean = data[column_name].mean()

# Calculate Median
median = data[column_name].median()

# Calculate Mode
mode = data[column_name].mode()[0]

# Calculate Variance
variance = data[column_name].var()

# Calculate Standard Deviation
std_dev = data[column_name].std()

# Calculate Range
data_range = data[column_name].max() - data[column_name].min()

# Calculate Skewness
skewness = data[column_name].skew()

# Detect Outliers using IQR method
Q1 = data[column_name].quantile(0.25)
Q3 = data[column_name].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = data[(data[column_name] < lower_bound) | (data[column_name] > upper_bound)]

# Print the results
print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode}")
print(f"Variance: {variance}")
print(f"Standard Deviation: {std_dev}")
print(f"Range: {data_range}")
print(f"Skewness: {skewness}")
print(f"Outliers:\n{outliers}")
# Out:
# Mean: 128800.10164835164
# Median: 101950.5
# Mode: 2461.0
# Variance: 13973567282.383587
# Standard Deviation: 118209.8442701943
# Range: 668529.0
# Skewness: 1.3343953416174976
# Outliers:
#       ID  Video Duration   Video Publish Time  Days Since Publish  Day  Month  \
# 108  108           677.0  2017-07-05 00:00:00                   0    5      7
# 142  142           520.0  2017-09-15 00:00:00                   3   15      9
# 149  149           862.0  2017-10-06 00:00:00                   4    6     10
# 188  188           731.0  2018-03-02 00:00:00                   5    2      3
# 196  196           877.0  2018-04-13 00:00:00                   6   13      4
# 228  228           639.0  2018-10-30 00:00:00                   8   30     10
#
#      Year Day of Week  Revenue per 1000 Views (USD)  \
# 108  2017   Wednesday                         0.029
# 142  2017      Friday                         0.018
# 149  2017      Friday                         0.060
# ...
